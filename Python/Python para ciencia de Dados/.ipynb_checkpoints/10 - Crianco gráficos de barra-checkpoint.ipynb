# %% [markdown]
# ### 10 - Crianco gráficos de barra

# %%
import pandas as pd

from matplotlib import pyplot as plt
from matplotlib import rcParams 

import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5,4

#5 polegadas de altura e 4 polegadas de largura

sns.set_style('whitegrid')

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
caminho = r'C:\Users\edmag\OneDrive\Área de Trabalho\Estudos\Python\Python para ciencia de Dados\dados\mtcars.csv'
carros = pd.read_csv(caminho)
carros.columns = ['nomes', 'mpg', 'cyl', 'disp', 'hpt', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', ' carb']

# %%
mpg = carros['mpg']
mpg.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
mpg.plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
# plt.savefig("nome da figura.png")
# conferindo se a imagem foi salva
# ! dir
