# %% [markdown]
# ### 9 - Crianco gráficos de linha

# %%
import pandas as pd

from matplotlib import pyplot as plt
from matplotlib import rcParams 

import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5,4

#5 polegadas de altura e 4 polegadas de largura

sns.set_style('whitegrid')

# %% [markdown]
# #### Desenhando gráfico de linha usando matplotlib

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]
plt.plot(x,y)

# %%
caminho = r'C:\Users\edmag\OneDrive\Área de Trabalho\Estudos\Python\Python para ciencia de Dados\dados\mtcars.csv'
carros = pd.read_csv(caminho)
carros.columns = ['nomes', 'mpg', 'cyl', 'disp', 'hpt', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', ' carb']

# %%
df = carros[['mpg', 'cyl', 'wt']]
df.plot()
# Out:
# <AxesSubplot:>
